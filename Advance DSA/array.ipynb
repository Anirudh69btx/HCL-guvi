# %%
# Write a brute force code
ar = [2,5,11,13,7]
k = 9
for i in range(len(ar)):
    for j in range(i + 1, len(ar)):
        if ar[i] + ar[j] == k:
            print("The combination for the sum of k=9 is",ar[i],"and", ar[j])
# Out:
# The combination for the sum of k=9 is 2 and 7

# %%
ar = [2,5,11,13,7,1,4,10,11,43,20,14,17]
k = 23
for i in range(len(ar)):
    for j in range(i + 1, len(ar)):
        for m in range(j+1, len(ar)):
            if ar[i] + ar[j]+ar[m] == k:
                print("The combination for the sum of k=23 is",ar[i],"and", ar[j],"and",ar[m])
# Out:
# The combination for the sum of k=23 is 2 and 11 and 10
# The combination for the sum of k=23 is 2 and 7 and 14
# The combination for the sum of k=23 is 2 and 1 and 20
# The combination for the sum of k=23 is 2 and 4 and 17
# The combination for the sum of k=23 is 2 and 10 and 11
# The combination for the sum of k=23 is 5 and 11 and 7
# The combination for the sum of k=23 is 5 and 7 and 11
# The combination for the sum of k=23 is 5 and 1 and 17
# The combination for the sum of k=23 is 5 and 4 and 14
# The combination for the sum of k=23 is 11 and 1 and 11

# %%
ar = [2, 5, 11, 13, 7]
k = 9
ar.sort()
left = 0
right = len(ar) - 1
while left < right:
    current_sum = ar[left] + ar[right]
    if current_sum == k:
        print("The combination for the sum of k=9 is",
                ar[left], "and", ar[right])
        break
    elif current_sum < k:
        left += 1
    else:
        right -= 1
